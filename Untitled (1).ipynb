# %%
import os 
os.getcwd()
# Out:
# '/drive/notebooks/it326'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking       Diet      Continent  Heart Attack Risk
# 0               0        1    Average  South America                  0
# 1               1        1  Unhealthy  North America                  0
# 2               0        0    Healthy         Europe                  0
# 3               1        1    Average  North America                  0
# 4               1        1  Unhealthy           Asia                  0

# %%
data=df['Continent'].value_counts(normalize=True)*100

# %%
print(data)
# Out:
# Continent
# Asia             29.882471
# Europe           25.531383
# South America    15.703926
# Australia        10.302576
# North America     9.552388
# Africa            9.027257
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(7, 7))
plt.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90)
plt.title('Heart Attack Incidence by continent')
plt.show()

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Cholesterol'}>,
#         <AxesSubplot:title={'center':'Heart Rate'}>],
#        [<AxesSubplot:title={'center':'Diabetes'}>,
#         <AxesSubplot:title={'center':'Family History'}>,
#         <AxesSubplot:title={'center':'Smoking'}>],
#        [<AxesSubplot:title={'center':'Heart Attack Risk'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
data2=df['Smoking'].value_counts(normalize=True)*100

# %%
plt.figure(figsize=(6, 4))
data2.plot(kind='bar', color=['skyblue', 'lightgreen'])
plt.title('Smoking')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %%
data3=df['Diet'].value_counts(normalize=True)*100

# %%
plt.figure(figsize=(6, 4))
data3.plot(kind='bar', color=['skyblue', 'lightgreen'])
plt.title('Diet')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(data3, labels=data3.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.4))
plt.title('Diet')
plt.show()

# %%
data4=df['Heart Attack Risk'].value_counts(normalize=True)*100

# %%
plt.figure(figsize=(6, 6))
plt.pie(data, labels=['0', '1'], autopct='%1.1f%%', startangle=90, colors=['#FFB6C1', '#800080'], wedgeprops=dict(width=0.4))
plt.title('Heart Attack Risk')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 plt.figure(figsize=(6, 6))
# ----> 2 plt.pie(data, labels=['0', '1'], autopct='%1.1f%%', startangle=90, colors=['#FFB6C1', '#800080'], wedgeprops=dict(width=0.4))
#       3 plt.title('Heart Attack Risk')
#       4 plt.show()
#
# File /lib/python3.12/site-packages/matplotlib/pyplot.py:2756, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2749 @_copy_docstring_and_deprecators(Axes.pie)
#    2750 def pie(
#    2751         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
#    2758         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2759         labeldistance=labeldistance, startangle=startangle,
#    2760         radius=radius, counterclock=counterclock,
#    2761         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2762         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2763         **({"data": data} if data is not None else {}))
#
# File /lib/python3.12/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File /lib/python3.12/site-packages/matplotlib/axes/_axes.py:3058, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3056     explode = [0] * len(x)
#    3057 if len(x) != len(labels):
# -> 3058     raise ValueError("'label' must be of length 'x'")
#    3059 if len(x) != len(explode):
#    3060     raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'
